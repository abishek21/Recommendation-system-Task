# %%
import pandas as pd

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
movies=pd.read_csv('D:\\recommendation system task\\movies_metadata.csv')
# Out:
# C:\Users\abishek\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=movies[['overview','title','genres','id']]

# %%
df['id']=df['id'].astype(str)
# Out:
# C:\Users\abishek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from ast import literal_eval

# %%
df['genres'] = df['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
# Out:
# C:\Users\abishek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['genres']=df['genres'].astype(str)
# Out:
# C:\Users\abishek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['overview']=df['overview'].astype(str)
# Out:
# C:\Users\abishek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *

# %%
stemmer = SnowballStemmer("english")

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\abishek\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# #  function to perform the pre processing steps on the entire dataset

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

# %%
processed_docs = []

for doc in df['overview']:
    processed_docs.append(preprocess(doc))

# %%
processed_docs
# Out:
# [['woodi',
#   'andi',
#   'toy',
#   'live',
#   'happili',
#   'room',
#   'andi',
#   'birthday',
#   'bring',
#   'buzz',
#   'lightyear',
#   'scene',
#   'afraid',
#   'lose',
#   'place',
#   'andi',
#   'heart',
#   'woodi',
#   'plot',
#   'buzz',
#   'circumst',
#   'separ',
#   'buzz',
#   'woodi',
#   'owner',
#   'eventu',
#   'learn',
#   'asid',
#   'differ'],
#  ['sibl',
#   'judi',
#   'peter',
#   'discov',
#   'enchant',
#   'board',
#   'game',
#   'open',
#   'door',
#   'magic',
#   'world',
#   'unwit',
#   'invit',
#   'alan',
#   'adult',
#   'trap',
#   'insid',
#   'game',
#   'year',
#   'live',
#   'room',
#   'alan',
#   'hope',
#   'freedom',
#   'finish',
#   'game',
#   'prove',
#   'riski',
#   'run',
#   'giant',
#   'rhinoceros',
#   'evil',
#   'monkey',
#   'terrifi',
#   'creatur'],
#  ['famili',
#   'wed',
#   'reignit',
#   'ancient',
#   'feud',
#   'door',
#   'neighbor',
#   'fish',
#   'buddi',
#   'john',
#   'sultri',
#   'italian',
# ...

# %% [markdown]
# # Creating a dictionary to count the frequency of the words

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %% [markdown]
# # Feature extraction - Bag of words

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
document_num = 20
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 7 ("differ") appears 1 time.
# Word 11 ("learn") appears 1 time.
# Word 124 ("lead") appears 1 time.
# Word 237 ("spark") appears 1 time.
# Word 263 ("life") appears 1 time.
# Word 372 ("aren") appears 1 time.
# Word 373 ("barboni") appears 1 time.
# Word 374 ("bone") appears 1 time.
# Word 375 ("boss") appears 1 time.
# Word 376 ("cheesi") appears 1 time.
# Word 377 ("chili") appears 3 time.
# Word 378 ("collect") appears 1 time.
# Word 379 ("debt") appears 1 time.
# Word 380 ("film") appears 1 time.
# Word 381 ("get") appears 1 time.
# Word 382 ("harri") appears 2 time.
# Word 383 ("hollywood") appears 2 time.
# Word 384 ("horror") appears 1 time.
# Word 385 ("idea") appears 1 time.
# Word 386 ("ladi") appears 1 time.
# Word 387 ("meet") appears 1 time.
# Word 388 ("miami") appears 1 time.
# Word 389 ("mobster") appears 2 time.
# Word 390 ("movi") appears 1 time.
# Word 391 ("palmer") appears 1 time.
# Word 392 ("pitch") appears 1 time.
# Word 393 ("produc") appears 2 time.
# ...

# %% [markdown]
# # LDA - Training the corpus
# initially i tried with 8 topic later i found 5 topics made more sense.

# %%
'''
Train your lda model using gensim.models.LdaMulticore and save it to 'lda_model'
'''
# TODO
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
'''
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.047*"film" + 0.011*"stori" + 0.011*"documentari" + 0.009*"movi" + 0.008*"life" + 0.008*"featur" + 0.007*"director" + 0.007*"star" + 0.007*"music" + 0.007*"base"
#
#
# Topic: 1
# Words: 0.022*"murder" + 0.016*"polic" + 0.010*"crime" + 0.010*"investig" + 0.009*"killer" + 0.008*"team" + 0.008*"detect" + 0.008*"kill" + 0.007*"case" + 0.007*"crimin"
#
#
# Topic: 2
# Words: 0.013*"world" + 0.009*"mysteri" + 0.008*"human" + 0.007*"power" + 0.006*"earth" + 0.006*"life" + 0.006*"magic" + 0.005*"discov" + 0.005*"dark" + 0.005*"time"
#
#
# Topic: 3
# Words: 0.015*"famili" + 0.012*"young" + 0.011*"father" + 0.011*"life" + 0.011*"live" + 0.010*"year" + 0.010*"love" + 0.009*"mother" + 0.009*"woman" + 0.008*"wife"
#
#
# Topic: 4
# Words: 0.020*"stori" + 0.014*"world" + 0.007*"life" + 0.005*"true" + 0.005*"german" + 0.005*"tell" + 0.005*"journey" + 0.004*"year" + 0.004*"take" + 0.004*"live"
#
#
# Topic: 5
# ...

# %%
unseen_document = df.iloc[10,0]
print(unseen_document)
# Out:
# Widowed U.S. president Andrew Shepherd, one of the world's most powerful men, can have anything he wants -- and what he covets most is Sydney Ellen Wade, a Washington lobbyist. But Shepherd's attempts at courting her spark wild rumors and decimate his approval ratings.

# %%
# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.3902694284915924	 Topic: 0.007*"group" + 0.007*"fight" + 0.006*"forc" + 0.006*"town" + 0.005*"kill"
# Score: 0.3889363706111908	 Topic: 0.015*"famili" + 0.012*"young" + 0.011*"father" + 0.011*"life" + 0.011*"live"
# Score: 0.19353261590003967	 Topic: 0.011*"drug" + 0.007*"state" + 0.006*"polit" + 0.006*"prison" + 0.005*"unit"

# %%
df.iloc[10,1]
# Out:
# 'The American President'

# %%
df.iloc[10,2]
# Out:
# "['Comedy', 'Drama', 'Romance']"

# %%
unseen_document = df.iloc[120,0]
print(unseen_document)
# Out:
# Marcus is a successful advertising executive who woos and beds women almost at will. After a company merger he finds that his new boss, the ravishing Jacqueline, is treating him in exactly the same way. Completely traumatised by this, his work goes badly downhill.

# %%
# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.5093358755111694	 Topic: 0.016*"love" + 0.012*"friend" + 0.010*"life" + 0.009*"school" + 0.008*"girl"
# Score: 0.30490267276763916	 Topic: 0.015*"famili" + 0.012*"young" + 0.011*"father" + 0.011*"life" + 0.011*"live"
# Score: 0.10162267088890076	 Topic: 0.011*"drug" + 0.007*"state" + 0.006*"polit" + 0.006*"prison" + 0.005*"unit"
# Score: 0.061324592679739	 Topic: 0.022*"murder" + 0.016*"polic" + 0.010*"crime" + 0.010*"investig" + 0.009*"killer"

# %%
df.iloc[120,1]
# Out:
# 'Boomerang'

# %%
df.iloc[120,2]
# Out:
# "['Comedy', 'Romance']"

# %% [markdown]
# # considering only 5 topics

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 5, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %% [markdown]
# ## topic 0 mostly likely to movies associated with crime
# ## topic 1 mostly likely to movies associated with fight,war
# ## topic 2 mostly likely to movies associated with life,love feel good movies
# ## topic 3 mostly likely to movies associated with love,romance
# ## topic 4 mostly likely to movies associated with documentary movies,music

# %%
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.015*"murder" + 0.009*"polic" + 0.009*"kill" + 0.007*"young" + 0.006*"crime" + 0.006*"prison" + 0.006*"investig" + 0.006*"killer" + 0.006*"death" + 0.005*"mysteri"
#
#
# Topic: 1
# Words: 0.008*"world" + 0.005*"fight" + 0.005*"team" + 0.005*"forc" + 0.004*"group" + 0.004*"power" + 0.004*"battl" + 0.004*"human" + 0.004*"save" + 0.004*"earth"
#
#
# Topic: 2
# Words: 0.013*"life" + 0.013*"love" + 0.011*"famili" + 0.011*"young" + 0.010*"live" + 0.009*"year" + 0.009*"friend" + 0.008*"girl" + 0.008*"father" + 0.007*"mother"
#
#
# Topic: 3
# Words: 0.008*"love" + 0.007*"wife" + 0.006*"marri" + 0.006*"money" + 0.006*"fall" + 0.004*"husband" + 0.004*"get" + 0.004*"woman" + 0.004*"decid" + 0.004*"plan"
#
#
# Topic: 4
# Words: 0.026*"film" + 0.011*"stori" + 0.007*"life" + 0.006*"documentari" + 0.006*"world" + 0.006*"movi" + 0.006*"music" + 0.005*"star" + 0.004*"live" + 0.004*"director"

# %%
unseen_document = df.iloc[10,0]
print(unseen_document)
# Out:
# Widowed U.S. president Andrew Shepherd, one of the world's most powerful men, can have anything he wants -- and what he covets most is Sydney Ellen Wade, a Washington lobbyist. But Shepherd's attempts at courting her spark wild rumors and decimate his approval ratings.

# %%
# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.5370452404022217	 Topic: 0.008*"world" + 0.005*"fight" + 0.005*"team" + 0.005*"forc" + 0.004*"group"
# Score: 0.31046250462532043	 Topic: 0.013*"life" + 0.013*"love" + 0.011*"famili" + 0.011*"young" + 0.010*"live"
# Score: 0.13463544845581055	 Topic: 0.026*"film" + 0.011*"stori" + 0.007*"life" + 0.006*"documentari" + 0.006*"world"

# %%
unseen_document = df.iloc[120,0]
print(unseen_document)
# Out:
# Marcus is a successful advertising executive who woos and beds women almost at will. After a company merger he finds that his new boss, the ravishing Jacqueline, is treating him in exactly the same way. Completely traumatised by this, his work goes badly downhill.

# %%
# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.3886420428752899	 Topic: 0.013*"life" + 0.013*"love" + 0.011*"famili" + 0.011*"young" + 0.010*"live"
# Score: 0.3581414520740509	 Topic: 0.008*"world" + 0.005*"fight" + 0.005*"team" + 0.005*"forc" + 0.004*"group"
# Score: 0.23448391258716583	 Topic: 0.008*"love" + 0.007*"wife" + 0.006*"marri" + 0.006*"money" + 0.006*"fall"

# %%
import pyLDAvis
# Out:
# C:\Users\abishek\Anaconda3\lib\site-packages\past\types\oldstr.py:33: DeprecationWarning: invalid escape sequence \d
#   """

# %%
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus,dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.012648  0.000883       1        1  32.206573
# 1     -0.068990 -0.111137       2        1  22.238920
# 4     -0.189588  0.160998       3        1  21.542448
# 0      0.008309 -0.152206       4        1  15.567620
# 3      0.237621  0.101462       5        1   8.444437, topic_info=     Category         Freq         Term        Total  loglift  logprob
# term
# 380   Default  6695.000000         film  6695.000000  30.0000  30.0000
# 167   Default  2873.000000       murder  2873.000000  29.0000  29.0000
# 503   Default  6116.000000         love  6116.000000  28.0000  28.0000
# 1482  Default  1727.000000        polic  1727.000000  27.0000  27.0000
# 913   Default  2538.000000       mother  2538.000000  26.0000  26.0000
# 114   Default  2503.000000         wife  2503.000000  25.0000  25.0000
# 60    Default  4942.000000       famili  4942.000000  24.0000  24.0000
# ...

# %% [markdown]
# # hover over topic area to get more details

# %%
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el990816750553193445114714693"></div>
# <script type="text/javascript">
#
# ...
